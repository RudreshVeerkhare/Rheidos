# %%
from __future__ import annotations

import time

from kung_fu_panda.engine import Engine
from kung_fu_panda.views.axes import AxesView

# %%
eng = Engine(interactive=True, auto_start=True, fps=60)  # window renders, cell returns
# # later cells…
# eng.add_view(MyView(...))
# eng.add_controller(MyController(...))
# # when done:
# await eng.stop_async()   # or eng.stop() in blocking apps
# Out:
# Known pipe types:
#   CocoaGraphicsPipe
# (all display modules loaded.)

# %%
from kung_fu_panda.views import AxesView, MeshSurfaceView, MeshWireframeView

# %%
eng.add_view(AxesView(axis_length=1.5, sort=0))
